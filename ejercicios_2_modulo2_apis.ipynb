# %%
#nombre, apellido y equipo
#estraer info en 200 jugadores, devuelve en dataFrames
#25 por peticcion y maximo de 100 por peticion

# %%
import requests

# %%
import pandas as pd

# %%
import re

# %%
url="https://api.balldontlie.io/v1/players"

# %%
import requests
tu_api_key_aqui='3c350989-596a-4b3f-8fe0-8ecbad9e2c1c'

response1 = requests.get(f"http://api.balldontlie.io/v1/players", 
        headers={'Authorization': tu_api_key_aqui},
        params={'cursor': 0, 'per_page': 100})


response = requests.get(f"http://api.balldontlie.io/v1/players", 
        headers={'Authorization': tu_api_key_aqui},
        params={'cursor': 100, 'per_page': 100})

info=response.json()

response.json()

#hay que sacar nombre, apellido y club

info1=response1.json()

print(info)

jugadores={}



for info in range(0,101):
   print( nombre=info['data']['0']['first_name'])
  dict_preg = {}


#ejemplo con la clase que nos ha dado cesar

#for cat in range(9, 11):
 #   url = f"https://opentdb.com/api.php?amount=10&category={cat}&difficulty=easy"
    #response = requests.get(url)
    #preg = response.json()
    #cat = preg["results"][0]["category"]
    #dict_preg[cat] = []
    #time.sleep(6)
# Out:
# {'data': [{'id': 101, 'first_name': 'John', 'last_name': 'Collins', 'position': 'F-C', 'height': '6-9', 'weight': '226', 'jersey_number': '20', 'college': 'Wake Forest', 'country': 'USA', 'draft_year': 2017, 'draft_round': 1, 'draft_number': 19, 'team': {'id': 13, 'conference': 'West', 'division': 'Pacific', 'city': 'LA', 'name': 'Clippers', 'full_name': 'LA Clippers', 'abbreviation': 'LAC'}}, {'id': 102, 'first_name': 'Zach', 'last_name': 'Collins', 'position': 'F-C', 'height': '6-9', 'weight': '240', 'jersey_number': '12', 'college': 'Gonzaga', 'country': 'USA', 'draft_year': 2017, 'draft_round': 1, 'draft_number': 10, 'team': {'id': 5, 'conference': 'East', 'division': 'Central', 'city': 'Chicago', 'name': 'Bulls', 'full_name': 'Chicago Bulls', 'abbreviation': 'CHI'}}, {'id': 103, 'first_name': 'Darren', 'last_name': 'Collison', 'position': 'G', 'height': '6-0', 'weight': '175', 'jersey_number': '2', 'college': 'UCLA', 'country': 'USA', 'draft_year': 2009, 'draft_round': 1, 'draft
# ...
