# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# %%
url = "https://api.github.com/users/Dacil235"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"login":"Dacil235","id":257940354,"node_id":"U_kgDOD1_bgg","avatar_url":"https://avatars.githubusercontent.com/u/257940354?v=4","gravatar_id":"","url":"https://api.github.com/users/Dacil235","html_url":"https://github.com/Dacil235","followers_url":"https://api.github.com/users/Dacil235/followers","following_url":"https://api.github.com/users/Dacil235/following{/other_user}","gists_url":"https://api.github.com/users/Dacil235/gists{/gist_id}","starred_url":"https://api.github.com/users/Dacil235/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/Dacil235/subscriptions","organizations_url":"https://api.github.com/users/Dacil235/orgs","repos_url":"https://api.github.com/users/Dacil235/repos","events_url":"https://api.github.com/users/Dacil235/events{/privacy}","received_events_url":"https://api.github.com/users/Dacil235/received_events","type":"User","user_view_type":"public","site_admin":false,"name":null,"company":null,"blog":"","location":null,"email":null,"hi
# ...

# %%
response.json()
# Out:
# {'login': 'Dacil235',
#  'id': 257940354,
#  'node_id': 'U_kgDOD1_bgg',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/257940354?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Dacil235',
#  'html_url': 'https://github.com/Dacil235',
#  'followers_url': 'https://api.github.com/users/Dacil235/followers',
#  'following_url': 'https://api.github.com/users/Dacil235/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Dacil235/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Dacil235/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Dacil235/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Dacil235/orgs',
#  'repos_url': 'https://api.github.com/users/Dacil235/repos',
#  'events_url': 'https://api.github.com/users/Dacil235/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Dacil235/received_events',
#  'type': 'User',
#  'user_view_type': 'public',
# ...

# %%
url2 = "https://api.github.com/users/gootyfer"

# %%
response = requests.get(url2)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"login":"gootyfer","id":759396,"node_id":"MDQ6VXNlcjc1OTM5Ng==","avatar_url":"https://avatars.githubusercontent.com/u/759396?v=4","gravatar_id":"","url":"https://api.github.com/users/gootyfer","html_url":"https://github.com/gootyfer","followers_url":"https://api.github.com/users/gootyfer/followers","following_url":"https://api.github.com/users/gootyfer/following{/other_user}","gists_url":"https://api.github.com/users/gootyfer/gists{/gist_id}","starred_url":"https://api.github.com/users/gootyfer/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/gootyfer/subscriptions","organizations_url":"https://api.github.com/users/gootyfer/orgs","repos_url":"https://api.github.com/users/gootyfer/repos","events_url":"https://api.github.com/users/gootyfer/events{/privacy}","received_events_url":"https://api.github.com/users/gootyfer/received_events","type":"User","user_view_type":"public","site_admin":false,"name":"Israel Guti\xc3\xa9rrez","company":null,"blog":"http://isra
# ...

# %%
response.json()
# Out:
# {'login': 'gootyfer',
#  'id': 759396,
#  'node_id': 'MDQ6VXNlcjc1OTM5Ng==',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/759396?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/gootyfer',
#  'html_url': 'https://github.com/gootyfer',
#  'followers_url': 'https://api.github.com/users/gootyfer/followers',
#  'following_url': 'https://api.github.com/users/gootyfer/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/gootyfer/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/gootyfer/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/gootyfer/subscriptions',
#  'organizations_url': 'https://api.github.com/users/gootyfer/orgs',
#  'repos_url': 'https://api.github.com/users/gootyfer/repos',
#  'events_url': 'https://api.github.com/users/gootyfer/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/gootyfer/received_events',
#  'type': 'User',
#  'user_view_type': 'public',
# ...

# %%
url3 = "https://api.github.com/users/saraguzmanlopez-ops"

# %%
response = requests.get(url3)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"login":"saraguzmanlopez-ops","id":257159262,"node_id":"U_kgDOD1PwXg","avatar_url":"https://avatars.githubusercontent.com/u/257159262?v=4","gravatar_id":"","url":"https://api.github.com/users/saraguzmanlopez-ops","html_url":"https://github.com/saraguzmanlopez-ops","followers_url":"https://api.github.com/users/saraguzmanlopez-ops/followers","following_url":"https://api.github.com/users/saraguzmanlopez-ops/following{/other_user}","gists_url":"https://api.github.com/users/saraguzmanlopez-ops/gists{/gist_id}","starred_url":"https://api.github.com/users/saraguzmanlopez-ops/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/saraguzmanlopez-ops/subscriptions","organizations_url":"https://api.github.com/users/saraguzmanlopez-ops/orgs","repos_url":"https://api.github.com/users/saraguzmanlopez-ops/repos","events_url":"https://api.github.com/users/saraguzmanlopez-ops/events{/privacy}","received_events_url":"https://api.github.com/users/saraguzmanlopez-ops/received_even
# ...

# %%
response.json()
# Out:
# {'login': 'saraguzmanlopez-ops',
#  'id': 257159262,
#  'node_id': 'U_kgDOD1PwXg',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/257159262?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/saraguzmanlopez-ops',
#  'html_url': 'https://github.com/saraguzmanlopez-ops',
#  'followers_url': 'https://api.github.com/users/saraguzmanlopez-ops/followers',
#  'following_url': 'https://api.github.com/users/saraguzmanlopez-ops/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/saraguzmanlopez-ops/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/saraguzmanlopez-ops/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/saraguzmanlopez-ops/subscriptions',
#  'organizations_url': 'https://api.github.com/users/saraguzmanlopez-ops/orgs',
#  'repos_url': 'https://api.github.com/users/saraguzmanlopez-ops/repos',
#  'events_url': 'https://api.github.com/users/saraguzmanlopez-ops/events{/privacy}',
# ...

# %%
url4 = "https://swapi.py4e.com/api/"

# %%
response = requests.get(url4)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"people":"https://swapi.py4e.com/api/people/","planets":"https://swapi.py4e.com/api/planets/","films":"https://swapi.py4e.com/api/films/","species":"https://swapi.py4e.com/api/species/","vehicles":"https://swapi.py4e.com/api/vehicles/","starships":"https://swapi.py4e.com/api/starships/"}'

# %%
response.json()
# Out:
# {'people': 'https://swapi.py4e.com/api/people/',
#  'planets': 'https://swapi.py4e.com/api/planets/',
#  'films': 'https://swapi.py4e.com/api/films/',
#  'species': 'https://swapi.py4e.com/api/species/',
#  'vehicles': 'https://swapi.py4e.com/api/vehicles/',
#  'starships': 'https://swapi.py4e.com/api/starships/'}

# %%
url_people = "https://swapi.py4e.com/api/people/"

# %%
response = requests.get(url_people)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"count":87,"next":"https://swapi.py4e.com/api/people/?page=2","previous":null,"results":[{"name":"Luke Skywalker","height":"172","mass":"77","hair_color":"blond","skin_color":"fair","eye_color":"blue","birth_year":"19BBY","gender":"male","homeworld":"https://swapi.py4e.com/api/planets/1/","films":["https://swapi.py4e.com/api/films/1/","https://swapi.py4e.com/api/films/2/","https://swapi.py4e.com/api/films/3/","https://swapi.py4e.com/api/films/6/","https://swapi.py4e.com/api/films/7/"],"species":["https://swapi.py4e.com/api/species/1/"],"vehicles":["https://swapi.py4e.com/api/vehicles/14/","https://swapi.py4e.com/api/vehicles/30/"],"starships":["https://swapi.py4e.com/api/starships/12/","https://swapi.py4e.com/api/starships/22/"],"created":"2014-12-09T13:50:51.644000Z","edited":"2014-12-20T21:17:56.891000Z","url":"https://swapi.py4e.com/api/people/1/"},{"name":"C-3PO","height":"167","mass":"75","hair_color":"n/a","skin_color":"gold","eye_color":"yellow","birth_year":"112BBY","gende
# ...

# %%
response.json()
# Out:
# {'count': 87,
#  'next': 'https://swapi.py4e.com/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.py4e.com/api/planets/1/',
#    'films': ['https://swapi.py4e.com/api/films/1/',
#     'https://swapi.py4e.com/api/films/2/',
#     'https://swapi.py4e.com/api/films/3/',
#     'https://swapi.py4e.com/api/films/6/',
#     'https://swapi.py4e.com/api/films/7/'],
#    'species': ['https://swapi.py4e.com/api/species/1/'],
#    'vehicles': ['https://swapi.py4e.com/api/vehicles/14/',
#     'https://swapi.py4e.com/api/vehicles/30/'],
#    'starships': ['https://swapi.py4e.com/api/starships/12/',
#     'https://swapi.py4e.com/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
# ...

# %%
datos = response.json()

# %%
type(datos)
# Out:
# dict

# %%
datos.keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])
